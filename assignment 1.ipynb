# %%
import pandas as pd

# %%
df=pd.read_csv("jsrt_metadata.csv")

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# ...

# %%
import numpy as np

# %%
df.replace("_",np.nan,inplace=True)

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety     93
# size         93
# age           0
# gender        0
# x            93
# y            93
# state         0
# position     93
# diagnosis    93
# dtype: int64

# %%
m=df["subtlety"].astype('float').mean()

# %%
m=int(m)

# %%
# replace nan with mean
df["subtlety"].replace(np.nan,m,inplace=True)

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       2.0   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       2.0   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       2.0   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       2.0   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       2.0   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# ...

# %%
m=df["size"].astype('float').median()

# %%
df["size"].replace(np.nan,m,inplace=True)

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       2.0  15.0  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       2.0  15.0  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       2.0  15.0  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       2.0  15.0  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       2.0  15.0  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# ...

# %%
m=df["x"].astype('float').median()

# %%
df["x"].replace(np.nan,m,inplace=True)

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       2.0  15.0  50    Male   668.0     NaN  non-nodule
# 243  JPCNN090.png       2.0  15.0  68  Female   668.0     NaN  non-nodule
# 244  JPCNN091.png       2.0  15.0  81    Male   668.0     NaN  non-nodule
# 245  JPCNN092.png       2.0  15.0  70  Female   668.0     NaN  non-nodule
# 246  JPCNN093.png       2.0  15.0  41    Male   668.0     NaN  non-nodule
#
#                position           diagnosis
# ...

# %%
m=df["y"].astype('float').median()

# %%
df["y"].replace(np.nan,m,inplace=True)

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       2.0  15.0  50    Male   668.0   864.0  non-nodule
# 243  JPCNN090.png       2.0  15.0  68  Female   668.0   864.0  non-nodule
# 244  JPCNN091.png       2.0  15.0  81    Male   668.0   864.0  non-nodule
# 245  JPCNN092.png       2.0  15.0  70  Female   668.0   864.0  non-nodule
# 246  JPCNN093.png       2.0  15.0  41    Male   668.0   864.0  non-nodule
#
#                position           diagnosis
# ...

# %%
df["position"].value_counts().max()
# Out:
# 16

# %%
# st equls to which values is maximum
St=df["position"].value_counts().idxmax()

# %%
df["position"].replace(np.nan,St,inplace=True)

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       2.0  15.0  50    Male   668.0   864.0  non-nodule
# 243  JPCNN090.png       2.0  15.0  68  Female   668.0   864.0  non-nodule
# 244  JPCNN091.png       2.0  15.0  81    Male   668.0   864.0  non-nodule
# 245  JPCNN092.png       2.0  15.0  70  Female   668.0   864.0  non-nodule
# 246  JPCNN093.png       2.0  15.0  41    Male   668.0   864.0  non-nodule
#
#                position           diagnosis
# ...

# %%
df["diagnosis"].value_counts().min()
# Out:
# 1

# %%
St=df["diagnosis"].value_counts().idxmin()

# %%
df["diagnosis"].replace(np.nan,St,inplace=True)

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       2.0  15.0  50    Male   668.0   864.0  non-nodule
# 243  JPCNN090.png       2.0  15.0  68  Female   668.0   864.0  non-nodule
# 244  JPCNN091.png       2.0  15.0  81    Male   668.0   864.0  non-nodule
# 245  JPCNN092.png       2.0  15.0  70  Female   668.0   864.0  non-nodule
# 246  JPCNN093.png       2.0  15.0  41    Male   668.0   864.0  non-nodule
#
#                position                          diagnosis
# ...

# %%
df.isnull().sum()
# Out:
# study_id     0
# subtlety     0
# size         0
# age          0
# gender       0
# x            0
# y            0
# state        0
# position     0
# diagnosis    0
# dtype: int64

# %%
st='malignant'

# %%
df.replace("non-nodule",np.nan,inplace=True)

# %%
df["state"].replace(np.nan,st,inplace=True)

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y      state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0  malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0     benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0  malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0     benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0  malignant
# ..            ...       ...   ...  ..     ...     ...     ...        ...
# 242  JPCNN089.png       2.0  15.0  50    Male   668.0   864.0  malignant
# 243  JPCNN090.png       2.0  15.0  68  Female   668.0   864.0  malignant
# 244  JPCNN091.png       2.0  15.0  81    Male   668.0   864.0  malignant
# 245  JPCNN092.png       2.0  15.0  70  Female   668.0   864.0  malignant
# 246  JPCNN093.png       2.0  15.0  41    Male   668.0   864.0  malignant
#
#                position                          diagnosis
# ...

# %%
import matplotlib as plt
from matplotlib import pyplot
from matplotlib import figure
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # part 1:

# %%
plt.pyplot.title("No.of patients of each disease")
plt.pyplot.xlabel("Disease")
plt.pyplot.ylabel("NO. of Patients")
plt.pyplot.hist(df['diagnosis'],color='cyan',ec='black')
# Out:
# (array([74., 33., 13.,  5.,  8.,  7.,  3., 96.,  4.,  4.]),
#  array([ 0. ,  3.1,  6.2,  9.3, 12.4, 15.5, 18.6, 21.7, 24.8, 27.9, 31. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # part 2;

# %%
plt.pyplot.pie(df[['diagnosis','state']].value_counts(),shadow=True,autopct='%1.1f%%',startangle=90,radius=4)
# Out:
# ([<matplotlib.patches.Wedge at 0x25e28dfd8e0>,
# ...
#  [Text(-4.09389429097415, 1.61246070784043, ''),
#   Text(-0.16784995834730687, -4.396797287968006, ''),
#   Text(3.6211290414346, -2.4994848399778182, ''),
#   Text(4.36082026708069, -0.5858725102087474, ''),
#   Text(4.353016016447805, 0.6412889836484705, ''),
#   Text(4.152426077492087, 1.455114315428065, ''),
#   Text(3.9089314041809646, 2.0199641772585553, ''),
#   Text(3.6835324658136295, 2.406571954730829, ''),
#   Text(3.4200290860051816, 2.7682848572498036, ''),
#   Text(3.160339775649243, 3.0614134811307823, ''),
#   Text(2.9593918428934742, 3.2560712400399914, ''),
#   Text(2.7899782604164707, 3.4023552586999917, ''),
#   Text(2.6133447479804106, 3.5398346328893964, ''),
#   Text(2.4299483993219364, 3.668153592290372, ''),
#   Text(2.240263809103969, 3.7869800719859854, ''),
#   Text(2.04478184475552, 3.896006571780676, ''),
#   Text(1.8440083762006916, 3.994950951951937, ''),
# ...

# %% [markdown]
# # part 3

# %%
plt.pyplot.pie(df[['diagnosis','gender']].value_counts(),shadow=True,autopct='%1.1f%%',startangle=90,radius=4)
# Out:
# ([<matplotlib.patches.Wedge at 0x25e2914d6a0>,
# ...
#  [Text(-2.7025359529446717, 3.472218228026781, ''),
#   Text(-4.221051685541953, -1.242063874357289, ''),
#   Text(-1.4814918641429495, -4.143088444201771, ''),
#   Text(1.586393428527052, -4.104065775536034, ''),
#   Text(3.3485107967442507, -2.8543782937948476, ''),
#   Text(4.051556521686832, -1.7160681080822242, ''),
#   Text(4.325383830137542, -0.8068796205040057, ''),
#   Text(4.399911026864786, -0.027981345101090394, ''),
#   Text(4.360820225940673, 0.5858728164258395, ''),
#   Text(4.265361104931039, 1.0801364008964185, ''),
#   Text(4.133583033547094, 1.5078101023575918, ''),
#   Text(3.9831430988746277, 1.869377183418967, ''),
#   Text(3.8290289536617697, 2.167610959563514, ''),
#   Text(3.652626031900895, 2.4532270728735903, ''),
#   Text(3.489334498025039, 2.6804001120900502, ''),
#   Text(3.3485104292807226, 2.8543787248713572, ''),
#   Text(3.199021056182755, 3.0209707516126953, ''),
# ...
